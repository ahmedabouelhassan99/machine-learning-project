# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedabouelhassan99/machine-learning-project/blob/main/ahmed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
canceranalysis_df = pd.read_csv("canceranalysis_database.csv")
canceranalysis_df.head()

#The file has been

canceranalysis_df.describe()
# Out:
#             length    subTypes  oncoTreeLevel     appeared       pubChem  \
# count  1453.000000  854.000000     854.000000   130.000000  8.700000e+01
# mean     11.044735    2.152225       3.152225  1983.161538  2.631455e+06
# std       3.132089   10.019220       1.144952    38.162201  8.061799e+06
# min       3.000000    0.000000       1.000000  1771.000000  1.071000e+03
# 25%      10.000000    0.000000       2.000000  1967.250000  5.352500e+03
# 50%      12.000000    0.000000       3.000000  1990.500000  6.083800e+04
# 75%      12.000000    0.000000       4.000000  2011.000000  4.529610e+05
# max      28.000000  120.000000       6.000000  2023.000000  5.467007e+07
#
#        domainName_registered  twitter_followers  usNewsRank  \
# count              74.000000       6.200000e+01   46.000000
# mean             2002.256757       2.081537e+05   23.521739
# std                 8.142668       7.543082e+05   13.642644
# min              1988.000000       3.000000e+00    1.000000
# ...

# %%
#impport library for ploting graphs
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#drop unecessary columns
#canceranalysis_df = canceranalysis_df.drop(["facebook_followers"],axis=1)

# %%
canceranalysis_df.describe()
# Out:
#             length    subTypes  oncoTreeLevel     appeared       pubChem  \
# count  1453.000000  854.000000     854.000000   130.000000  8.700000e+01
# mean     11.044735    2.152225       3.152225  1983.161538  2.631455e+06
# std       3.132089   10.019220       1.144952    38.162201  8.061799e+06
# min       3.000000    0.000000       1.000000  1771.000000  1.071000e+03
# 25%      10.000000    0.000000       2.000000  1967.250000  5.352500e+03
# 50%      12.000000    0.000000       3.000000  1990.500000  6.083800e+04
# 75%      12.000000    0.000000       4.000000  2011.000000  4.529610e+05
# max      28.000000  120.000000       6.000000  2023.000000  5.467007e+07
#
#        domainName_registered  usNewsRank  uscsCasesPerYear  uscsDeathsPerYear  \
# count              74.000000   46.000000         25.000000          24.000000
# mean             2002.256757   23.521739      64217.400000       21961.500000
# ...

# %%
canceranalysis_df.rename (columns = {'domainName_registered':'domainNameregistered'}, inplace = True)

# %%
canceranalysis_df.describe()
# Out:
#             length    subTypes  oncoTreeLevel     appeared       pubChem  \
# count  1453.000000  854.000000     854.000000   130.000000  8.700000e+01
# mean     11.044735    2.152225       3.152225  1983.161538  2.631455e+06
# std       3.132089   10.019220       1.144952    38.162201  8.061799e+06
# min       3.000000    0.000000       1.000000  1771.000000  1.071000e+03
# 25%      10.000000    0.000000       2.000000  1967.250000  5.352500e+03
# 50%      12.000000    0.000000       3.000000  1990.500000  6.083800e+04
# 75%      12.000000    0.000000       4.000000  2011.000000  4.529610e+05
# max      28.000000  120.000000       6.000000  2023.000000  5.467007e+07
#
#        domainNameregistered  usNewsRank  uscsCasesPerYear  uscsDeathsPerYear  \
# count             74.000000   46.000000         25.000000          24.000000
# mean            2002.256757   23.521739      64217.400000       21961.500000
# std                8.142668   13.642644      72765.400444       28776.299522
# ...

# %%
canceranalysis_df.head()
# Out:
#                                  title  length  \
# 0  Jonsson Comprehensive Cancer Center      22
# 1                          Skin Cancer      28
# 2                       Bladder Cancer      26
# 3                        Breast Cancer      26
# 4                          Lung Cancer      26
#
#                                     id             type  \
# 0  jonsson-comprehensive-cancer-center  nciCancerCenter
# 1                                 skin       cancerType
# 2                       bladder-cancer       cancerType
# 3                               breast       cancerType
# 4                                 lung       cancerType
#
#                   tissue  subTypes  oncoTreeLevel  \
# 0                    NaN       NaN            NaN
# 1                   Skin      29.0            1.0
# 2  Bladder/Urinary Tract      17.0            1.0
# 3                 Breast      35.0            1.0
# 4                   Lung      29.0            1.0
#
# ...

# %%
#drop unecessary columns
canceranalysis_df = canceranalysis_df.drop(["length", "wikipedia", "website", "domainName", "twitter", "reference", "standsFor", "phoneNumber", "pubChem", "kegg", "nciDesignation", "nciLink", "drugBank", "medlinePlus", "tradenames", "usNewsRank", "parentOrganization", "hostSchool", "aka", "author", "uscsTable", "uscsCasesPerYear", "uscsMortalityRate", "uscsDeathsPerYear", "gco", "uscsId", "cancerDotOrg", "amazon", "ein", "subreddit_members", "subreddit", "charityNavigator", "cancerDotGov", "nyse", "nasdaq", "related", "annualDeathsReport", "greatNonProfits", "guideStar", "oldName", "company", "youTube", "isOpenSource", "closed", "originCommunity", "members", "pdf", "githubRepo", "investorRelationsPage", "englandAndWalesCharityDetails", "isPublicDomain", "journal", "nextDate", "publicationFrequency", "wolframAlpha", "eventsPage", "github", "vimeo", "telegram", "rumble", "gab", "coursera"],axis=1)

# %%
canceranalysis_df.head()
# Out:
#                                  title                                   id  \
# 0  Jonsson Comprehensive Cancer Center  jonsson-comprehensive-cancer-center
# 1                          Skin Cancer                                 skin
# 2                       Bladder Cancer                       bladder-cancer
# 3                        Breast Cancer                               breast
# 4                          Lung Cancer                                 lung
#
#               type                 tissue  subTypes  oncoTreeLevel  \
# 0  nciCancerCenter                    NaN       NaN            NaN
# 1       cancerType                   Skin      29.0            1.0
# 2       cancerType  Bladder/Urinary Tract      17.0            1.0
# 3       cancerType                 Breast      35.0            1.0
# 4       cancerType                   Lung      29.0            1.0
#
#                             mainType parentOncoTreeId oncoTreeId      umls  \
# ...

# %%
canceranalysis_df = canceranalysis_df.drop(["facebook","nciImage", "linkedin",  "instagram", "youTubeChannel",],axis=1)

# %%
canceranalysis_df.head()
# Out:
#                                  title                                   id  \
# 0  Jonsson Comprehensive Cancer Center  jonsson-comprehensive-cancer-center
# 1                          Skin Cancer                                 skin
# 2                       Bladder Cancer                       bladder-cancer
# 3                        Breast Cancer                               breast
# 4                          Lung Cancer                                 lung
#
#               type                 tissue  subTypes  oncoTreeLevel  \
# 0  nciCancerCenter                    NaN       NaN            NaN
# 1       cancerType                   Skin      29.0            1.0
# 2       cancerType  Bladder/Urinary Tract      17.0            1.0
# 3       cancerType                 Breast      35.0            1.0
# 4       cancerType                   Lung      29.0            1.0
#
#                             mainType parentOncoTreeId oncoTreeId      umls  \
# ...

# %%
sns.pairplot(canceranalysis_df)
plt.show()

# %%
numerical_summary = canceranalysis_df.describe().transpose()
numerical_summary
# Out:
#                       count         mean        std     min      25%     50%  \
# subTypes              854.0     2.152225  10.019220     0.0     0.00     0.0
# oncoTreeLevel         854.0     3.152225   1.144952     1.0     2.00     3.0
# appeared              130.0  1983.161538  38.162201  1771.0  1967.25  1990.5
# domainNameregistered   74.0  2002.256757   8.142668  1988.0  1996.00  1999.0
#
#                           75%     max
# subTypes                 0.00   120.0
# oncoTreeLevel            4.00     6.0
# appeared              2011.00  2023.0
# domainNameregistered  2009.75  2020.0

# %%
# Get the summary of the data
data_summary = {
    "Number of Rows": canceranalysis_df.shape[0],
    "Number of Columns": canceranalysis_df.shape[1],
    "Missing Values": canceranalysis_df.isnull().sum().sum(),
    "Data Types": canceranalysis_df.dtypes.value_counts().to_dict()
}

data_summary
# Out:
# {'Number of Rows': 1453,
#  'Number of Columns': 19,
#  'Missing Values': 16210,
#  'Data Types': {dtype('O'): 15, dtype('float64'): 4}}
